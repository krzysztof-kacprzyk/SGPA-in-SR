# %%
from gplearn_sgpa._program import _Program
import numpy as np
from gplearn_sgpa.sgpa import *
from gplearn_sgpa.genetic import _convert_to_sympy, _check_if_finite
from gplearn_sgpa.functions import _function_map
import sympy as sp
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import pearsonr, spearmanr

# %%
n_equations = 10000

FUNCTION_SET = ('add', 'sub', 'mul', 'div', 'sqrt', 'log', 'sin', 'exp')
function_set = [_function_map[f] for f in FUNCTION_SET]

arities = {}
for function in function_set:
    arity = function.arity
    arities[arity] = arities.get(arity, [])
    arities[arity].append(function)

init_depth=(2, 6)
init_method='half and half'
const_range=(-1, 1)
metric='mean absolute error'
p_point_replace=0.05
parsimony_coefficient=0.001


# Generate a list of random equations
gen = np.random.default_rng(seed=0)

# Generate a list of random states
seeds = gen.integers(0, 1e9, size=n_equations)
n_features_list = gen.integers(1, 10, size=n_equations)
states = [np.random.RandomState(seed) for seed in seeds]

programs = [_Program(function_set,arities,init_depth,init_method,n_features,const_range,metric,p_point_replace,parsimony_coefficient,state) for state, n_features in zip(states, n_features_list)]

# %%
c1_list = []
new_programs = []
sympy_exp_list = []
for program in programs:
    sympy_exp = _convert_to_sympy(program.program)
    
    if _check_if_finite(sympy_exp):
        new_programs.append(program)
        c1_list.append(complexity_1(sympy_exp, empirical=True))
        sympy_exp_list.append(sympy_exp)
# Out:
# <lambdifygenerated-2>:2: RuntimeWarning: overflow encountered in exp
#   return -sqrt(exp(1.94924425764298*exp(X1)/(log(abs(X0))*log(abs(X1))))/(sqrt(abs(X1))*sqrt(abs(log(abs(X1))))))*exp((1/2)*X0)*abs(X1 + sin(X0) - 0.788703945680358)**(1/4) + sqrt(exp(1.94924425764298*exp(X1 + l)/(log(abs(X0))*log(abs(X1 + l))))/(sqrt(abs(X1 + l))*sqrt(abs(log(abs(X1 + l))))))*exp((1/2)*X0)*abs(X1 + l + sin(X0) - 0.788703945680358)**(1/4)
# <lambdifygenerated-5>:2: RuntimeWarning: overflow encountered in exp
#   return -sqrt(exp(1.94924425764298*exp(X1)/(log(abs(X0))*log(abs(X1))))/(sqrt(abs(X1))*sqrt(abs(log(abs(X1))))))*exp((1/2)*X0)*abs(X1 + sin(X0) - 0.788703945680358)**(1/4) + sqrt(exp(1.94924425764298*exp(X1)/(log(abs(X1))*log(abs(X0 + l))))/(sqrt(abs(X1))*sqrt(abs(log(abs(X1))))))*exp((1/2)*X0 + (1/2)*l)*abs(X1 + sin(X0 + l) - 0.788703945680358)**(1/4)
# <lambdifygenerated-7>:2: RuntimeWarning: overflow encountered in exp
#   return -exp((log(abs(X0)) + 0.903266733865905)*exp(-X0) - 0.493431189718617/abs(X0)) + exp((log(abs(X0 + l)) + 0.903266733865905)*exp(-X0 - l) - 0.493431189718617/abs(X0 + l))
# <lambdifygenerated-79>:2: RuntimeWarning: overflow encountered in exp
#   return -log(exp(sqrt(abs((X5 + 0.300106711724445)*sin(X5)))/log(abs((X0 - X3)*(X1 - X2))))) + log(exp(sqrt(abs((X5 + 0.300106711724445)*sin(X5)))/log(abs((X1 - X2)*(-X0 + X3 + l)))))
# <lambdifygenerated-84>:2: RuntimeWarning: overflow encountered in exp
#   return -log(exp(sqrt(abs((X5 + 0.300106711724445)*sin(X5)))/log(abs((X0 - X3)*(X1 - X2))))) + log(exp(sqrt(abs((X5 + 0.300106711724445)*sin(X5)))/log(abs((X0 - X3)*(X1 - X2 + l)))))
# <lambdifygenerated-89>:2: RuntimeWarning: overflow encountered in exp
#   return -log(exp(sqrt(abs((X5 + 0.300106711724445)*sin(X5)))/log(abs((X0 - X3)*(X1 - X2))))) + log(exp(sqrt(abs((X5 + 0.300106711724445)*sin(X5)))/log(abs((X1 - X2)*(X0 - X3 + l)))))
# <lambdifygenerated-94>:2: RuntimeWarning: overflow encountered in exp
#   return -log(exp(sqrt(abs((X5 + 0.300106711724445)*sin(X5)))/log(abs((X0 - X3)*(X1 - X2))))) + log(exp(sqrt(abs((X5 + l + 0.300106711724445)*sin(X5 + l)))/log(abs((X0 - X3)*(X1 - X2)))))
# <lambdifygenerated-94>:2: RuntimeWarning: invalid value encountered in add
#   return -log(exp(sqrt(abs((X5 + 0.300106711724445)*sin(X5)))/log(abs((X0 - X3)*(X1 - X2))))) + log(exp(sqrt(abs((X5 + l + 0.300106711724445)*sin(X5 + l)))/log(abs((X0 - X3)*(X1 - X2)))))
# <lambdifygenerated-99>:2: RuntimeWarning: overflow encountered in exp
#   return -log(exp(sqrt(abs((X5 + 0.300106711724445)*sin(X5)))/log(abs((X0 - X3)*(X1 - X2))))) + log(exp(sqrt(abs((X5 + 0.300106711724445)*sin(X5)))/log(abs((X0 - X3)*(-X1 + X2 + l)))))
# <lambdifygenerated-102>:2: RuntimeWarning: overflow encountered in exp
#   return -2.02248452875274*(X0 - 2*exp(X0))*exp(-0.467740736581814/X0)/((log(abs(X0)) + 0.32693554835255)*sqrt(abs(sqrt(abs(X0)) - 1.26001639806754))) + 0.325511309009066*exp(X0) + exp((1/2)*X0**2)*sqrt(abs(X0 + sin(X0) + 0.950234883179334)) - 0.325511309009066*exp(X0 + l) - exp((1/2)*(X0 + l)**2)*sqrt(abs(X0 + l + sin(X0 + l) + 0.950234883179334)) - sqrt(abs(X0)) + sqrt(abs(X0 + l)) + sqrt(abs(X0 + l))/(X0 + l - 0.537728045920044) + 2.02248452875274*(X0 + l - 2*exp(X0 + l))*exp(-0.467740736581814/(X0 + l))/((log(abs(X0 + l)) + 0.32693554835255)*sqrt(abs(sqrt(abs(X0 + l)) - 1.26001639806754))) - sqrt(abs(X0))/(X0 - 0.537728045920044)
# <lambdifygenerated-212>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(exp(X6) + sin(X3 + 0.80957162412991) - 1) + exp(exp(X6) + sin(X3 + l + 0.80957162412991) - 1)
# <lambdifygenerated-212>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(exp(X6) + sin(X3 + 0.80957162412991) - 1) + exp(exp(X6) + sin(X3 + l + 0.80957162412991) - 1)
# <lambdifygenerated-214>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(exp(X6) + sin(X3 + 0.80957162412991) - 1) + exp(exp(X6 + l) + sin(X3 + 0.80957162412991) - 1)
# <lambdifygenerated-214>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(exp(X6) + sin(X3 + 0.80957162412991) - 1) + exp(exp(X6 + l) + sin(X3 + 0.80957162412991) - 1)
# <lambdifygenerated-215>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(exp(X6) + sin(X3 + 0.80957162412991) - 1) + exp(exp(X6 + l) + sin(X3 + 0.80957162412991) - 1)
# <lambdifygenerated-290>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(exp(exp(X1)*sin(X2))) + exp(exp(exp(X1 + l)*sin(X2)))
# <lambdifygenerated-291>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(exp(exp(X1)*sin(X2))) + exp(exp(exp(X1 + l)*sin(X2)))
# <lambdifygenerated-291>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(exp(exp(X1)*sin(X2))) + exp(exp(exp(X1 + l)*sin(X2)))
# <lambdifygenerated-293>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(exp(exp(X1)*sin(X2))) + exp(exp(exp(X1)*sin(X2 + l)))
# <lambdifygenerated-293>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(exp(exp(X1)*sin(X2))) + exp(exp(exp(X1)*sin(X2 + l)))
# <lambdifygenerated-295>:2: RuntimeWarning: overflow encountered in exp
#   return -sqrt(exp(2.1745681884039*exp(-X1)*exp(sin(exp(X8)))*cos((1/4)*arctan2(0, abs(X4)))/abs(X4)**(1/4))) + sqrt(exp(2.1745681884039*exp(-X1)*exp(sin(exp(X8)))*cos((1/4)*arctan2(0, abs(X4 + l)))/abs(X4 + l)**(1/4)))
# <lambdifygenerated-295>:2: RuntimeWarning: invalid value encountered in add
#   return -sqrt(exp(2.1745681884039*exp(-X1)*exp(sin(exp(X8)))*cos((1/4)*arctan2(0, abs(X4)))/abs(X4)**(1/4))) + sqrt(exp(2.1745681884039*exp(-X1)*exp(sin(exp(X8)))*cos((1/4)*arctan2(0, abs(X4 + l)))/abs(X4 + l)**(1/4)))
# <lambdifygenerated-297>:2: RuntimeWarning: overflow encountered in exp
#   return -sqrt(exp(2.1745681884039*exp(-X1)*exp(sin(exp(X8)))*cos((1/4)*arctan2(0, abs(X4)))/abs(X4)**(1/4))) + sqrt(exp(2.1745681884039*exp(-X1)*exp(sin(exp(X8)))*cos((1/4)*arctan2(0, abs(X4 + l)))/abs(X4 + l)**(1/4)))
# <lambdifygenerated-297>:2: RuntimeWarning: invalid value encountered in add
#   return -sqrt(exp(2.1745681884039*exp(-X1)*exp(sin(exp(X8)))*cos((1/4)*arctan2(0, abs(X4)))/abs(X4)**(1/4))) + sqrt(exp(2.1745681884039*exp(-X1)*exp(sin(exp(X8)))*cos((1/4)*arctan2(0, abs(X4 + l)))/abs(X4 + l)**(1/4)))
# <lambdifygenerated-298>:2: RuntimeWarning: overflow encountered in exp
#   return -sqrt(exp(2.1745681884039*exp(-X1)*exp(sin(exp(X8)))*cos((1/4)*arctan2(0, abs(X4)))/abs(X4)**(1/4))) + sqrt(exp(2.1745681884039*exp(-X1 - l)*exp(sin(exp(X8)))*cos((1/4)*arctan2(0, abs(X4)))/abs(X4)**(1/4)))
# <lambdifygenerated-298>:2: RuntimeWarning: invalid value encountered in add
#   return -sqrt(exp(2.1745681884039*exp(-X1)*exp(sin(exp(X8)))*cos((1/4)*arctan2(0, abs(X4)))/abs(X4)**(1/4))) + sqrt(exp(2.1745681884039*exp(-X1 - l)*exp(sin(exp(X8)))*cos((1/4)*arctan2(0, abs(X4)))/abs(X4)**(1/4)))
# <lambdifygenerated-299>:2: RuntimeWarning: overflow encountered in exp
#   return -sqrt(exp(2.1745681884039*exp(-X1)*exp(sin(exp(X8)))*cos((1/4)*arctan2(0, abs(X4)))/abs(X4)**(1/4))) + sqrt(exp(2.1745681884039*exp(-X1 - l)*exp(sin(exp(X8)))*cos((1/4)*arctan2(0, abs(X4)))/abs(X4)**(1/4)))
# <lambdifygenerated-300>:2: RuntimeWarning: overflow encountered in exp
#   return -sqrt(exp(2.1745681884039*exp(-X1)*exp(sin(exp(X8)))*cos((1/4)*arctan2(0, abs(X4)))/abs(X4)**(1/4))) + sqrt(exp(2.1745681884039*exp(-X1 - l)*exp(sin(exp(X8)))*cos((1/4)*arctan2(0, abs(X4)))/abs(X4)**(1/4)))
# <lambdifygenerated-300>:2: RuntimeWarning: invalid value encountered in add
#   return -sqrt(exp(2.1745681884039*exp(-X1)*exp(sin(exp(X8)))*cos((1/4)*arctan2(0, abs(X4)))/abs(X4)**(1/4))) + sqrt(exp(2.1745681884039*exp(-X1 - l)*exp(sin(exp(X8)))*cos((1/4)*arctan2(0, abs(X4)))/abs(X4)**(1/4)))
# <lambdifygenerated-301>:2: RuntimeWarning: overflow encountered in exp
#   return -sqrt(exp(2.1745681884039*exp(-X1)*exp(sin(exp(X8)))*cos((1/4)*arctan2(0, abs(X4)))/abs(X4)**(1/4))) + sqrt(exp(2.1745681884039*exp(-X1)*exp(sin(exp(X8 + l)))*cos((1/4)*arctan2(0, abs(X4)))/abs(X4)**(1/4)))
# <lambdifygenerated-301>:2: RuntimeWarning: invalid value encountered in add
#   return -sqrt(exp(2.1745681884039*exp(-X1)*exp(sin(exp(X8)))*cos((1/4)*arctan2(0, abs(X4)))/abs(X4)**(1/4))) + sqrt(exp(2.1745681884039*exp(-X1)*exp(sin(exp(X8 + l)))*cos((1/4)*arctan2(0, abs(X4)))/abs(X4)**(1/4)))
# <lambdifygenerated-303>:2: RuntimeWarning: overflow encountered in exp
#   return -sqrt(exp(2.1745681884039*exp(-X1)*exp(sin(exp(X8)))*cos((1/4)*arctan2(0, abs(X4)))/abs(X4)**(1/4))) + sqrt(exp(2.1745681884039*exp(-X1)*exp(sin(exp(X8 + l)))*cos((1/4)*arctan2(0, abs(X4)))/abs(X4)**(1/4)))
# <lambdifygenerated-303>:2: RuntimeWarning: invalid value encountered in add
#   return -sqrt(exp(2.1745681884039*exp(-X1)*exp(sin(exp(X8)))*cos((1/4)*arctan2(0, abs(X4)))/abs(X4)**(1/4))) + sqrt(exp(2.1745681884039*exp(-X1)*exp(sin(exp(X8 + l)))*cos((1/4)*arctan2(0, abs(X4)))/abs(X4)**(1/4)))
# <lambdifygenerated-371>:2: RuntimeWarning: overflow encountered in exp
#   return exp(0.0173016551510343*exp(X2)) - exp(0.0173016551510343*exp(X2 + l)) - sin((-X1 + 1.80448147352703*X2)*(0.422001362846913*X2 + log(abs(X1)))) + sin((-X1 + 1.80448147352703*X2 + 1.80448147352703*l)*(0.422001362846913*X2 + 0.422001362846913*l + log(abs(X1))))
# <lambdifygenerated-423>:2: RuntimeWarning: overflow encountered in exp
#   return (exp(exp((X0 + l)**2)) + log(abs(sin(X8 - 0.512271841403741))))/(exp(exp(X0**2)) + log(abs(sin(X8 - 0.512271841403741))))
# <lambdifygenerated-423>:2: RuntimeWarning: invalid value encountered in divide
#   return (exp(exp((X0 + l)**2)) + log(abs(sin(X8 - 0.512271841403741))))/(exp(exp(X0**2)) + log(abs(sin(X8 - 0.512271841403741))))
# <lambdifygenerated-424>:2: RuntimeWarning: overflow encountered in exp
#   return (exp(exp((X0 + l)**2)) + log(abs(sin(X8 - 0.512271841403741))))/(exp(exp(X0**2)) + log(abs(sin(X8 - 0.512271841403741))))
# <lambdifygenerated-428>:2: RuntimeWarning: overflow encountered in exp
#   return (exp(exp(X0**2)) + log(abs(sin(X8 + l - 0.512271841403741))))*log(sqrt(abs(3.38222354441709*X8 + 3.38222354441709*l - 2.81634762450402)))/((exp(exp(X0**2)) + log(abs(sin(X8 - 0.512271841403741))))*log(sqrt(abs(3.38222354441709*X8 - 2.81634762450402))))
# <lambdifygenerated-428>:2: RuntimeWarning: invalid value encountered in divide
#   return (exp(exp(X0**2)) + log(abs(sin(X8 + l - 0.512271841403741))))*log(sqrt(abs(3.38222354441709*X8 + 3.38222354441709*l - 2.81634762450402)))/((exp(exp(X0**2)) + log(abs(sin(X8 - 0.512271841403741))))*log(sqrt(abs(3.38222354441709*X8 - 2.81634762450402))))
# <lambdifygenerated-440>:2: RuntimeWarning: overflow encountered in exp
#   return exp(-X5/X2)*exp((X5 + l)/X2)
# <lambdifygenerated-440>:2: RuntimeWarning: invalid value encountered in multiply
#   return exp(-X5/X2)*exp((X5 + l)/X2)
# <lambdifygenerated-443>:2: RuntimeWarning: overflow encountered in exp
#   return (X2 + X3)*exp(-X5/X2)*exp(X5/(X2 + l))/(X2 + X3 + l)
# <lambdifygenerated-449>:2: RuntimeWarning: overflow encountered in exp
#   return exp(-X1 + X3)*exp(X1 - X3)*exp(-exp(exp(exp(X0 - X4))))*exp(exp(exp(exp(X0 - X4 - l))))
# <lambdifygenerated-449>:2: RuntimeWarning: invalid value encountered in multiply
#   return exp(-X1 + X3)*exp(X1 - X3)*exp(-exp(exp(exp(X0 - X4))))*exp(exp(exp(exp(X0 - X4 - l))))
# <lambdifygenerated-450>:2: RuntimeWarning: overflow encountered in exp
#   return exp(-X1 + X3)*exp(X1 - X3)*exp(-exp(exp(exp(X0 - X4))))*exp(exp(exp(exp(X0 - X4 - l))))
# <lambdifygenerated-450>:2: RuntimeWarning: invalid value encountered in multiply
#   return exp(-X1 + X3)*exp(X1 - X3)*exp(-exp(exp(exp(X0 - X4))))*exp(exp(exp(exp(X0 - X4 - l))))
# <lambdifygenerated-451>:2: RuntimeWarning: overflow encountered in exp
#   return exp(-X1 + X3)*exp(X1 - X3)*exp(-exp(exp(exp(X0 - X4))))*exp(exp(exp(exp(X0 - X4 - l))))
# <lambdifygenerated-451>:2: RuntimeWarning: invalid value encountered in multiply
#   return exp(-X1 + X3)*exp(X1 - X3)*exp(-exp(exp(exp(X0 - X4))))*exp(exp(exp(exp(X0 - X4 - l))))
# <lambdifygenerated-452>:2: RuntimeWarning: overflow encountered in exp
#   return exp(-X1 + X3)*exp(X1 - X3)*exp(-exp(exp(exp(X0 - X4))))*exp(exp(exp(exp(X0 - X4 - l))))
# <lambdifygenerated-452>:2: RuntimeWarning: invalid value encountered in multiply
#   return exp(-X1 + X3)*exp(X1 - X3)*exp(-exp(exp(exp(X0 - X4))))*exp(exp(exp(exp(X0 - X4 - l))))
# <lambdifygenerated-453>:2: RuntimeWarning: overflow encountered in exp
#   return exp(-X0**2)*exp((X0 + l)**2)*exp(-X1 + X3)*exp(X1 - X3)*exp(-exp(exp(exp(X0 - X4))))*exp(exp(exp(exp(X0 - X4 + l))))*abs(X0)/abs(X0 + l)
# <lambdifygenerated-453>:2: RuntimeWarning: invalid value encountered in multiply
#   return exp(-X0**2)*exp((X0 + l)**2)*exp(-X1 + X3)*exp(X1 - X3)*exp(-exp(exp(exp(X0 - X4))))*exp(exp(exp(exp(X0 - X4 + l))))*abs(X0)/abs(X0 + l)
# <lambdifygenerated-454>:2: RuntimeWarning: overflow encountered in exp
#   return exp(-X0**2)*exp((X0 + l)**2)*exp(-X1 + X3)*exp(X1 - X3)*exp(-exp(exp(exp(X0 - X4))))*exp(exp(exp(exp(X0 - X4 + l))))*abs(X0)/abs(X0 + l)
# <lambdifygenerated-454>:2: RuntimeWarning: invalid value encountered in multiply
#   return exp(-X0**2)*exp((X0 + l)**2)*exp(-X1 + X3)*exp(X1 - X3)*exp(-exp(exp(exp(X0 - X4))))*exp(exp(exp(exp(X0 - X4 + l))))*abs(X0)/abs(X0 + l)
# <lambdifygenerated-455>:2: RuntimeWarning: overflow encountered in exp
#   return exp(-X0**2)*exp((X0 + l)**2)*exp(-X1 + X3)*exp(X1 - X3)*exp(-exp(exp(exp(X0 - X4))))*exp(exp(exp(exp(X0 - X4 + l))))*abs(X0)/abs(X0 + l)
# <lambdifygenerated-455>:2: RuntimeWarning: invalid value encountered in multiply
#   return exp(-X0**2)*exp((X0 + l)**2)*exp(-X1 + X3)*exp(X1 - X3)*exp(-exp(exp(exp(X0 - X4))))*exp(exp(exp(exp(X0 - X4 + l))))*abs(X0)/abs(X0 + l)
# <lambdifygenerated-456>:2: RuntimeWarning: overflow encountered in exp
#   return exp(-X0**2)*exp((X0 + l)**2)*exp(-X1 + X3)*exp(X1 - X3)*exp(-exp(exp(exp(X0 - X4))))*exp(exp(exp(exp(X0 - X4 + l))))*abs(X0)/abs(X0 + l)
# <lambdifygenerated-456>:2: RuntimeWarning: invalid value encountered in multiply
#   return exp(-X0**2)*exp((X0 + l)**2)*exp(-X1 + X3)*exp(X1 - X3)*exp(-exp(exp(exp(X0 - X4))))*exp(exp(exp(exp(X0 - X4 + l))))*abs(X0)/abs(X0 + l)
# <lambdifygenerated-473>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X2*X5*(X4 - X5)) + exp(X2*X5*(X4 - X5 + l))
# <lambdifygenerated-476>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X2*X5*(X4 - X5)) + exp(X5*(X2 + l)*(X4 - X5))
# <lambdifygenerated-477>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X2*X5*(X4 - X5)) + exp(X5*(X2 + l)*(X4 - X5))
# <lambdifygenerated-479>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X2*X5*(X4 - X5)) + exp(X2*(X5 + l)*(X4 - X5 - l))
# <lambdifygenerated-479>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(X2*X5*(X4 - X5)) + exp(X2*(X5 + l)*(X4 - X5 - l))
# <lambdifygenerated-481>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X2*X5*(X4 - X5)) + exp(X2*(X5 + l)*(X4 - X5 - l))
# <lambdifygenerated-507>:2: RuntimeWarning: overflow encountered in exp
#   return (-X4*(X3 + l) + exp(X0*(X3 + l)) - sin(X3 + l) - sin(X3 - X4 + l)*sqrt(abs(sin(X3 + l))))*exp(X0/X3)*exp(-X0/(X3 + l))/(-X3*X4 + exp(X0*X3) - sin(X3) - sin(X3 - X4)*sqrt(abs(sin(X3))))
# <lambdifygenerated-514>:2: RuntimeWarning: overflow encountered in exp
#   return (-X3*X4 + exp(X3*(X0 + l)) - sin(X3) - sin(X3 - X4)*sqrt(abs(sin(X3))))*exp(X0/X3)*exp(-X0*X4)*exp(-(X0 + l)/X3)*exp(X4*(X0 + l))/(-X3*X4 + exp(X0*X3) - sin(X3) - sin(X3 - X4)*sqrt(abs(sin(X3))))
# <lambdifygenerated-514>:2: RuntimeWarning: invalid value encountered in multiply
#   return (-X3*X4 + exp(X3*(X0 + l)) - sin(X3) - sin(X3 - X4)*sqrt(abs(sin(X3))))*exp(X0/X3)*exp(-X0*X4)*exp(-(X0 + l)/X3)*exp(X4*(X0 + l))/(-X3*X4 + exp(X0*X3) - sin(X3) - sin(X3 - X4)*sqrt(abs(sin(X3))))
# <lambdifygenerated-519>:2: RuntimeWarning: overflow encountered in exp
#   return (log(abs(sin(exp(X3 + l)))) + sin(X1 - X5)*sin(-X2 + X3 + l))*exp(X1**2*X2)/(X3 + l - sin(exp(exp(X0)))) - (log(abs(sin(exp(X3)))) - sin(X1 - X5)*sin(X2 - X3))*exp(X1**2*X2)/(X3 - sin(exp(exp(X0))))
# <lambdifygenerated-519>:2: RuntimeWarning: invalid value encountered in sin
#   return (log(abs(sin(exp(X3 + l)))) + sin(X1 - X5)*sin(-X2 + X3 + l))*exp(X1**2*X2)/(X3 + l - sin(exp(exp(X0)))) - (log(abs(sin(exp(X3)))) - sin(X1 - X5)*sin(X2 - X3))*exp(X1**2*X2)/(X3 - sin(exp(exp(X0))))
# <lambdifygenerated-520>:2: RuntimeWarning: overflow encountered in exp
#   return (log(abs(sin(exp(X3 + l)))) + sin(X1 - X5)*sin(-X2 + X3 + l))*exp(X1**2*X2)/(X3 + l - sin(exp(exp(X0)))) - (log(abs(sin(exp(X3)))) - sin(X1 - X5)*sin(X2 - X3))*exp(X1**2*X2)/(X3 - sin(exp(exp(X0))))
# <lambdifygenerated-520>:2: RuntimeWarning: invalid value encountered in sin
#   return (log(abs(sin(exp(X3 + l)))) + sin(X1 - X5)*sin(-X2 + X3 + l))*exp(X1**2*X2)/(X3 + l - sin(exp(exp(X0)))) - (log(abs(sin(exp(X3)))) - sin(X1 - X5)*sin(X2 - X3))*exp(X1**2*X2)/(X3 - sin(exp(exp(X0))))
# <lambdifygenerated-521>:2: RuntimeWarning: overflow encountered in exp
#   return (log(abs(sin(exp(X3 + l)))) + sin(X1 - X5)*sin(-X2 + X3 + l))*exp(X1**2*X2)/(X3 + l - sin(exp(exp(X0)))) - (log(abs(sin(exp(X3)))) - sin(X1 - X5)*sin(X2 - X3))*exp(X1**2*X2)/(X3 - sin(exp(exp(X0))))
# <lambdifygenerated-521>:2: RuntimeWarning: invalid value encountered in sin
#   return (log(abs(sin(exp(X3 + l)))) + sin(X1 - X5)*sin(-X2 + X3 + l))*exp(X1**2*X2)/(X3 + l - sin(exp(exp(X0)))) - (log(abs(sin(exp(X3)))) - sin(X1 - X5)*sin(X2 - X3))*exp(X1**2*X2)/(X3 - sin(exp(exp(X0))))
# <lambdifygenerated-522>:2: RuntimeWarning: overflow encountered in exp
#   return (log(abs(sin(exp(X3 + l)))) + sin(X1 - X5)*sin(-X2 + X3 + l))*exp(X1**2*X2)/(X3 + l - sin(exp(exp(X0)))) - (log(abs(sin(exp(X3)))) - sin(X1 - X5)*sin(X2 - X3))*exp(X1**2*X2)/(X3 - sin(exp(exp(X0))))
# <lambdifygenerated-522>:2: RuntimeWarning: invalid value encountered in subtract
#   return (log(abs(sin(exp(X3 + l)))) + sin(X1 - X5)*sin(-X2 + X3 + l))*exp(X1**2*X2)/(X3 + l - sin(exp(exp(X0)))) - (log(abs(sin(exp(X3)))) - sin(X1 - X5)*sin(X2 - X3))*exp(X1**2*X2)/(X3 - sin(exp(exp(X0))))
# <lambdifygenerated-523>:2: RuntimeWarning: overflow encountered in exp
#   return (log(abs(sin(exp(X3 + l)))) + sin(X1 - X5)*sin(-X2 + X3 + l))*exp(X1**2*X2)/(X3 + l - sin(exp(exp(X0)))) - (log(abs(sin(exp(X3)))) - sin(X1 - X5)*sin(X2 - X3))*exp(X1**2*X2)/(X3 - sin(exp(exp(X0))))
# <lambdifygenerated-523>:2: RuntimeWarning: invalid value encountered in sin
#   return (log(abs(sin(exp(X3 + l)))) + sin(X1 - X5)*sin(-X2 + X3 + l))*exp(X1**2*X2)/(X3 + l - sin(exp(exp(X0)))) - (log(abs(sin(exp(X3)))) - sin(X1 - X5)*sin(X2 - X3))*exp(X1**2*X2)/(X3 - sin(exp(exp(X0))))
# <lambdifygenerated-523>:2: RuntimeWarning: invalid value encountered in subtract
#   return (log(abs(sin(exp(X3 + l)))) + sin(X1 - X5)*sin(-X2 + X3 + l))*exp(X1**2*X2)/(X3 + l - sin(exp(exp(X0)))) - (log(abs(sin(exp(X3)))) - sin(X1 - X5)*sin(X2 - X3))*exp(X1**2*X2)/(X3 - sin(exp(exp(X0))))
# <lambdifygenerated-524>:2: RuntimeWarning: overflow encountered in exp
#   return (log(abs(sin(exp(X3)))) - sin(X2 - X3)*sin(X1 - X5 + l))*exp(-X1**2*X2)*exp(X2*(X1 + l)**2)/(log(abs(sin(exp(X3)))) - sin(X1 - X5)*sin(X2 - X3))
# <lambdifygenerated-526>:2: RuntimeWarning: overflow encountered in exp
#   return (log(abs(sin(exp(X3)))) - sin(X2 - X3)*sin(X1 - X5 + l))*exp(-X1**2*X2)*exp(X2*(X1 + l)**2)/(log(abs(sin(exp(X3)))) - sin(X1 - X5)*sin(X2 - X3))
# <lambdifygenerated-527>:2: RuntimeWarning: overflow encountered in exp
#   return (log(abs(sin(exp(X3)))) - sin(X2 - X3)*sin(X1 - X5 + l))*exp(-X1**2*X2)*exp(X2*(X1 + l)**2)/(log(abs(sin(exp(X3)))) - sin(X1 - X5)*sin(X2 - X3))
# <lambdifygenerated-528>:2: RuntimeWarning: overflow encountered in exp
#   return (X3 - sin(exp(exp(X0))))/(X3 - sin(exp(exp(X0 + l))))
# <lambdifygenerated-528>:2: RuntimeWarning: invalid value encountered in sin
#   return (X3 - sin(exp(exp(X0))))/(X3 - sin(exp(exp(X0 + l))))
# <lambdifygenerated-529>:2: RuntimeWarning: overflow encountered in exp
#   return (X3 - sin(exp(exp(X0))))/(X3 - sin(exp(exp(X0 + l))))
# <lambdifygenerated-529>:2: RuntimeWarning: invalid value encountered in sin
#   return (X3 - sin(exp(exp(X0))))/(X3 - sin(exp(exp(X0 + l))))
# <lambdifygenerated-534>:2: RuntimeWarning: overflow encountered in exp
#   return (log(abs(sin(exp(X3)))) - sin(X1 - X5)*sin(X2 - X3 + l))*exp(-X1**2*X2)*exp(X1**2*(X2 + l))/(log(abs(sin(exp(X3)))) - sin(X1 - X5)*sin(X2 - X3))
# <lambdifygenerated-535>:2: RuntimeWarning: overflow encountered in exp
#   return (log(abs(sin(exp(X3)))) - sin(X1 - X5)*sin(X2 - X3 + l))*exp(-X1**2*X2)*exp(X1**2*(X2 + l))/(log(abs(sin(exp(X3)))) - sin(X1 - X5)*sin(X2 - X3))
# <lambdifygenerated-537>:2: RuntimeWarning: overflow encountered in exp
#   return (log(abs(sin(exp(X3)))) - sin(X1 - X5)*sin(X2 - X3 + l))*exp(-X1**2*X2)*exp(X1**2*(X2 + l))/(log(abs(sin(exp(X3)))) - sin(X1 - X5)*sin(X2 - X3))
# <lambdifygenerated-537>:2: RuntimeWarning: overflow encountered in multiply
#   return (log(abs(sin(exp(X3)))) - sin(X1 - X5)*sin(X2 - X3 + l))*exp(-X1**2*X2)*exp(X1**2*(X2 + l))/(log(abs(sin(exp(X3)))) - sin(X1 - X5)*sin(X2 - X3))
# <lambdifygenerated-537>:2: RuntimeWarning: invalid value encountered in multiply
#   return (log(abs(sin(exp(X3)))) - sin(X1 - X5)*sin(X2 - X3 + l))*exp(-X1**2*X2)*exp(X1**2*(X2 + l))/(log(abs(sin(exp(X3)))) - sin(X1 - X5)*sin(X2 - X3))
# <lambdifygenerated-546>:2: RuntimeWarning: overflow encountered in exp
#   return -abs(log(exp(X7*log(abs(X2))/X1)))**(1/4) + abs(log(exp(X7*log(abs(X2))/(X1 + l))))**(1/4)
# <lambdifygenerated-546>:2: RuntimeWarning: divide by zero encountered in log
#   return -abs(log(exp(X7*log(abs(X2))/X1)))**(1/4) + abs(log(exp(X7*log(abs(X2))/(X1 + l))))**(1/4)
# <lambdifygenerated-548>:2: RuntimeWarning: overflow encountered in exp
#   return -abs(log(exp(X7*log(abs(X2))/X1)))**(1/4) + abs(log(exp(X7*log(abs(X2))/(X1 + l))))**(1/4)
# <lambdifygenerated-549>:2: RuntimeWarning: overflow encountered in exp
#   return -abs(log(exp(X7*log(abs(X2))/X1)))**(1/4) + abs(log(exp(X7*log(abs(X2 + l))/X1)))**(1/4)
# <lambdifygenerated-549>:2: RuntimeWarning: divide by zero encountered in log
#   return -abs(log(exp(X7*log(abs(X2))/X1)))**(1/4) + abs(log(exp(X7*log(abs(X2 + l))/X1)))**(1/4)
# <lambdifygenerated-549>:2: RuntimeWarning: invalid value encountered in add
#   return -abs(log(exp(X7*log(abs(X2))/X1)))**(1/4) + abs(log(exp(X7*log(abs(X2 + l))/X1)))**(1/4)
# <lambdifygenerated-552>:2: RuntimeWarning: overflow encountered in exp
#   return -abs(log(exp(X7*log(abs(X2))/X1)))**(1/4) + abs(log(exp((X7 + l)*log(abs(X2))/X1)))**(1/4)
# <lambdifygenerated-552>:2: RuntimeWarning: divide by zero encountered in log
#   return -abs(log(exp(X7*log(abs(X2))/X1)))**(1/4) + abs(log(exp((X7 + l)*log(abs(X2))/X1)))**(1/4)
# <lambdifygenerated-552>:2: RuntimeWarning: invalid value encountered in add
#   return -abs(log(exp(X7*log(abs(X2))/X1)))**(1/4) + abs(log(exp((X7 + l)*log(abs(X2))/X1)))**(1/4)
# <lambdifygenerated-576>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X2/X4) + exp(X2/(X4 + l))
# <lambdifygenerated-578>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X2/X4) + exp((X2 + l)/X4)
# <lambdifygenerated-578>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(X2/X4) + exp((X2 + l)/X4)
# <lambdifygenerated-698>:2: RuntimeWarning: overflow encountered in exp
#   return exp(2*X2/sin(X1)) - exp(2*(X2 + l)/sin(X1)) - log(abs(log(abs(X2 - 0.739604883923781)))) + log(abs(log(abs(X2 + l - 0.739604883923781)))) - 0.486508308592213*X2*exp(-X1)*sin(X1)/X1 + 0.486508308592213*(X2 + l)*exp(-X1)*sin(X1)/X1
# <lambdifygenerated-698>:2: RuntimeWarning: invalid value encountered in subtract
#   return exp(2*X2/sin(X1)) - exp(2*(X2 + l)/sin(X1)) - log(abs(log(abs(X2 - 0.739604883923781)))) + log(abs(log(abs(X2 + l - 0.739604883923781)))) - 0.486508308592213*X2*exp(-X1)*sin(X1)/X1 + 0.486508308592213*(X2 + l)*exp(-X1)*sin(X1)/X1
# <lambdifygenerated-699>:2: RuntimeWarning: overflow encountered in exp
#   return 0.486508308592213*X2*exp(-X1 - l)*sin(X1 + l)/(X1 + l) + exp(2*X2/sin(X1)) - exp(2*X2/sin(X1 + l)) - 0.486508308592213*X2*exp(-X1)*sin(X1)/X1
# <lambdifygenerated-700>:2: RuntimeWarning: overflow encountered in exp
#   return 0.486508308592213*X2*exp(-X1 - l)*sin(X1 + l)/(X1 + l) + exp(2*X2/sin(X1)) - exp(2*X2/sin(X1 + l)) - 0.486508308592213*X2*exp(-X1)*sin(X1)/X1
# <lambdifygenerated-766>:2: RuntimeWarning: overflow encountered in exp
#   return log(exp(X2/X3))/log(exp(X2/(X3 + l)))
# <lambdifygenerated-766>:2: RuntimeWarning: divide by zero encountered in log
#   return log(exp(X2/X3))/log(exp(X2/(X3 + l)))
# <lambdifygenerated-768>:2: RuntimeWarning: overflow encountered in exp
#   return log(exp(X2/X3))/log(exp((X2 + l)/X3))
# <lambdifygenerated-768>:2: RuntimeWarning: divide by zero encountered in log
#   return log(exp(X2/X3))/log(exp((X2 + l)/X3))
# <lambdifygenerated-768>:2: RuntimeWarning: invalid value encountered in divide
#   return log(exp(X2/X3))/log(exp((X2 + l)/X3))
# <lambdifygenerated-860>:2: RuntimeWarning: overflow encountered in exp
#   return sqrt(abs(log(exp(X5*sin(X8)/(X0 + l)))))/sqrt(abs(log(exp(X5*sin(X8)/X0))))
# <lambdifygenerated-863>:2: RuntimeWarning: overflow encountered in exp
#   return sqrt(abs(log(exp((X5 + l)*sin(X8)/X0))))/sqrt(abs(log(exp(X5*sin(X8)/X0))))
# <lambdifygenerated-863>:2: RuntimeWarning: divide by zero encountered in log
#   return sqrt(abs(log(exp((X5 + l)*sin(X8)/X0))))/sqrt(abs(log(exp(X5*sin(X8)/X0))))
# <lambdifygenerated-863>:2: RuntimeWarning: invalid value encountered in divide
#   return sqrt(abs(log(exp((X5 + l)*sin(X8)/X0))))/sqrt(abs(log(exp(X5*sin(X8)/X0))))
# <lambdifygenerated-868>:2: RuntimeWarning: overflow encountered in exp
#   return -sin(sin(4.06149171398012*(-X4 + X8)/X8) + 0.131138173867437 - sqrt(abs(X4))/log(abs(X1)))*sqrt(abs(log(exp(X5*sin(X8)/X0)))) + sin(sin(4.06149171398012*(-X4 + X8 + l)/(X8 + l)) + 0.131138173867437 - sqrt(abs(X4))/log(abs(X1)))*sqrt(abs(log(exp(X5*sin(X8 + l)/X0))))
# <lambdifygenerated-868>:2: RuntimeWarning: divide by zero encountered in log
#   return -sin(sin(4.06149171398012*(-X4 + X8)/X8) + 0.131138173867437 - sqrt(abs(X4))/log(abs(X1)))*sqrt(abs(log(exp(X5*sin(X8)/X0)))) + sin(sin(4.06149171398012*(-X4 + X8 + l)/(X8 + l)) + 0.131138173867437 - sqrt(abs(X4))/log(abs(X1)))*sqrt(abs(log(exp(X5*sin(X8 + l)/X0))))
# <lambdifygenerated-868>:2: RuntimeWarning: invalid value encountered in add
#   return -sin(sin(4.06149171398012*(-X4 + X8)/X8) + 0.131138173867437 - sqrt(abs(X4))/log(abs(X1)))*sqrt(abs(log(exp(X5*sin(X8)/X0)))) + sin(sin(4.06149171398012*(-X4 + X8 + l)/(X8 + l)) + 0.131138173867437 - sqrt(abs(X4))/log(abs(X1)))*sqrt(abs(log(exp(X5*sin(X8 + l)/X0))))
# <lambdifygenerated-1007>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4 - l)*sin(X1/X2)/X5)
# <lambdifygenerated-1007>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4 - l)*sin(X1/X2)/X5)
# <lambdifygenerated-1008>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4 - l)*sin(X1/X2)/X5)
# <lambdifygenerated-1008>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4 - l)*sin(X1/X2)/X5)
# <lambdifygenerated-1009>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4 - l)*sin(X1/X2)/X5)
# <lambdifygenerated-1009>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4 - l)*sin(X1/X2)/X5)
# <lambdifygenerated-1010>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4 - l)*sin(X1/X2)/X5)
# <lambdifygenerated-1010>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4 - l)*sin(X1/X2)/X5)
# <lambdifygenerated-1011>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4 - l)*sin(X1/X2)/X5)
# <lambdifygenerated-1011>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4 - l)*sin(X1/X2)/X5)
# <lambdifygenerated-1012>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4 + l)*sin((X1 + l)/X2)/X5)
# <lambdifygenerated-1012>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4 + l)*sin((X1 + l)/X2)/X5)
# <lambdifygenerated-1013>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4 + l)*sin((X1 + l)/X2)/X5)
# <lambdifygenerated-1014>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4 + l)*sin((X1 + l)/X2)/X5)
# <lambdifygenerated-1015>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4 + l)*sin((X1 + l)/X2)/X5)
# <lambdifygenerated-1016>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4 + l)*sin((X1 + l)/X2)/X5)
# <lambdifygenerated-1016>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4 + l)*sin((X1 + l)/X2)/X5)
# <lambdifygenerated-1017>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp((X0 + l)*(X1 - X4)*sin(X1/X2)/X5)
# <lambdifygenerated-1017>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp((X0 + l)*(X1 - X4)*sin(X1/X2)/X5)
# <lambdifygenerated-1018>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp((X0 + l)*(X1 - X4)*sin(X1/X2)/X5)
# <lambdifygenerated-1018>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp((X0 + l)*(X1 - X4)*sin(X1/X2)/X5)
# <lambdifygenerated-1019>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp((X0 + l)*(X1 - X4)*sin(X1/X2)/X5)
# <lambdifygenerated-1019>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp((X0 + l)*(X1 - X4)*sin(X1/X2)/X5)
# <lambdifygenerated-1020>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp((X0 + l)*(X1 - X4)*sin(X1/X2)/X5)
# <lambdifygenerated-1021>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp((X0 + l)*(X1 - X4)*sin(X1/X2)/X5)
# <lambdifygenerated-1021>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp((X0 + l)*(X1 - X4)*sin(X1/X2)/X5)
# <lambdifygenerated-1022>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4)*sin(X1/X2)/(X5 + l))
# <lambdifygenerated-1023>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4)*sin(X1/X2)/(X5 + l))
# <lambdifygenerated-1024>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4)*sin(X1/X2)/(X5 + l))
# <lambdifygenerated-1025>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4)*sin(X1/X2)/(X5 + l))
# <lambdifygenerated-1026>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4)*sin(X1/X2)/(X5 + l))
# <lambdifygenerated-1027>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4)*sin(X1/(X2 + l))/X5)
# <lambdifygenerated-1027>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4)*sin(X1/(X2 + l))/X5)
# <lambdifygenerated-1028>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4)*sin(X1/(X2 + l))/X5)
# <lambdifygenerated-1028>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4)*sin(X1/(X2 + l))/X5)
# <lambdifygenerated-1029>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4)*sin(X1/(X2 + l))/X5)
# <lambdifygenerated-1029>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4)*sin(X1/(X2 + l))/X5)
# <lambdifygenerated-1030>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4)*sin(X1/(X2 + l))/X5)
# <lambdifygenerated-1031>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4)*sin(X1/(X2 + l))/X5)
# <lambdifygenerated-1031>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(X0*(X1 - X4)*sin(X1/X2)/X5) + exp(X0*(X1 - X4)*sin(X1/(X2 + l))/X5)
# <lambdifygenerated-1138>:2: RuntimeWarning: overflow encountered in exp
#   return -sin(exp(2.83695464986623*X0*X1/sqrt(abs(X0))) + exp(-1.3174255508525*exp(-2*X0)*log(abs(X1)))) + sin(exp(2.83695464986623*X0*(X1 + l)/sqrt(abs(X0))) + exp(-1.3174255508525*exp(-2*X0)*log(abs(X1 + l))))
# <lambdifygenerated-1138>:2: RuntimeWarning: invalid value encountered in sin
#   return -sin(exp(2.83695464986623*X0*X1/sqrt(abs(X0))) + exp(-1.3174255508525*exp(-2*X0)*log(abs(X1)))) + sin(exp(2.83695464986623*X0*(X1 + l)/sqrt(abs(X0))) + exp(-1.3174255508525*exp(-2*X0)*log(abs(X1 + l))))
# <lambdifygenerated-1140>:2: RuntimeWarning: overflow encountered in exp
#   return -sin(exp(2.83695464986623*X0*X1/sqrt(abs(X0))) + exp(-1.3174255508525*exp(-2*X0)*log(abs(X1)))) + sin(exp(2.83695464986623*X1*(X0 + l)/sqrt(abs(X0 + l))) + exp(-1.3174255508525*exp(-2*X0 - 2*l)*log(abs(X1))))
# <lambdifygenerated-1140>:2: RuntimeWarning: invalid value encountered in sin
#   return -sin(exp(2.83695464986623*X0*X1/sqrt(abs(X0))) + exp(-1.3174255508525*exp(-2*X0)*log(abs(X1)))) + sin(exp(2.83695464986623*X1*(X0 + l)/sqrt(abs(X0 + l))) + exp(-1.3174255508525*exp(-2*X0 - 2*l)*log(abs(X1))))
# <lambdifygenerated-1141>:2: RuntimeWarning: overflow encountered in exp
#   return -sin(exp(2.83695464986623*X0*X1/sqrt(abs(X0))) + exp(-1.3174255508525*exp(-2*X0)*log(abs(X1)))) + sin(exp(2.83695464986623*X1*(X0 + l)/sqrt(abs(X0 + l))) + exp(-1.3174255508525*exp(-2*X0 - 2*l)*log(abs(X1))))
# <lambdifygenerated-1141>:2: RuntimeWarning: invalid value encountered in sin
#   return -sin(exp(2.83695464986623*X0*X1/sqrt(abs(X0))) + exp(-1.3174255508525*exp(-2*X0)*log(abs(X1)))) + sin(exp(2.83695464986623*X1*(X0 + l)/sqrt(abs(X0 + l))) + exp(-1.3174255508525*exp(-2*X0 - 2*l)*log(abs(X1))))
# <lambdifygenerated-1201>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(e*X0*exp((1/2)*X3)*sin(X0/X1)) + exp(e*X0*exp((1/2)*X3 + (1/2)*l)*sin(X0/X1)) + (X3**2 + X3 - X4)/X2 - (X3 - X4 + l + (X3 + l)**2)/X2
# <lambdifygenerated-1202>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(e*X0*exp((1/2)*X3)*sin(X0/X1)) + exp(e*X0*exp((1/2)*X3 + (1/2)*l)*sin(X0/X1)) + (X3**2 + X3 - X4)/X2 - (X3 - X4 + l + (X3 + l)**2)/X2
# <lambdifygenerated-1202>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(e*X0*exp((1/2)*X3)*sin(X0/X1)) + exp(e*X0*exp((1/2)*X3 + (1/2)*l)*sin(X0/X1)) + (X3**2 + X3 - X4)/X2 - (X3 - X4 + l + (X3 + l)**2)/X2
# <lambdifygenerated-1203>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(e*X0*exp((1/2)*X3)*sin(X0/X1)) + exp(e*X0*exp((1/2)*X3 + (1/2)*l)*sin(X0/X1)) + (X3**2 + X3 - X4)/X2 - (X3 - X4 + l + (X3 + l)**2)/X2
# <lambdifygenerated-1203>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(e*X0*exp((1/2)*X3)*sin(X0/X1)) + exp(e*X0*exp((1/2)*X3 + (1/2)*l)*sin(X0/X1)) + (X3**2 + X3 - X4)/X2 - (X3 - X4 + l + (X3 + l)**2)/X2
# <lambdifygenerated-1204>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(e*X0*exp((1/2)*X3)*sin(X0/X1)) + exp(e*X0*exp((1/2)*X3 + (1/2)*l)*sin(X0/X1)) + (X3**2 + X3 - X4)/X2 - (X3 - X4 + l + (X3 + l)**2)/X2
# <lambdifygenerated-1204>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(e*X0*exp((1/2)*X3)*sin(X0/X1)) + exp(e*X0*exp((1/2)*X3 + (1/2)*l)*sin(X0/X1)) + (X3**2 + X3 - X4)/X2 - (X3 - X4 + l + (X3 + l)**2)/X2
# <lambdifygenerated-1205>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(e*X0*exp((1/2)*X3)*sin(X0/X1)) + exp(e*X0*exp((1/2)*X3 + (1/2)*l)*sin(X0/X1)) + (X3**2 + X3 - X4)/X2 - (X3 - X4 + l + (X3 + l)**2)/X2
# <lambdifygenerated-1207>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(e*X0*exp((1/2)*X3)*sin(X0/X1)) + exp(e*X0*exp((1/2)*X3)*sin(X0/(X1 + l)))
# <lambdifygenerated-1207>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(e*X0*exp((1/2)*X3)*sin(X0/X1)) + exp(e*X0*exp((1/2)*X3)*sin(X0/(X1 + l)))
# <lambdifygenerated-1210>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(e*X0*exp((1/2)*X3)*sin(X0/X1)) + exp(e*(X0 + l)*exp((1/2)*X3)*sin((X0 + l)/X1)) + sin(X0) - sin(X0 + l) - abs(sin(X0))**(1/4) + abs(sin(X0 + l))**(1/4)
# <lambdifygenerated-1211>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(e*X0*exp((1/2)*X3)*sin(X0/X1)) + exp(e*(X0 + l)*exp((1/2)*X3)*sin((X0 + l)/X1)) + sin(X0) - sin(X0 + l) - abs(sin(X0))**(1/4) + abs(sin(X0 + l))**(1/4)
# <lambdifygenerated-1280>:2: RuntimeWarning: overflow encountered in exp
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X5*(X3 + l) + X6 - exp(X1/X4))))
# <lambdifygenerated-1280>:2: RuntimeWarning: invalid value encountered in subtract
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X5*(X3 + l) + X6 - exp(X1/X4))))
# <lambdifygenerated-1281>:2: RuntimeWarning: overflow encountered in exp
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X5*(X3 + l) + X6 - exp(X1/X4))))
# <lambdifygenerated-1281>:2: RuntimeWarning: invalid value encountered in subtract
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X5*(X3 + l) + X6 - exp(X1/X4))))
# <lambdifygenerated-1282>:2: RuntimeWarning: overflow encountered in exp
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X5*(X3 + l) + X6 - exp(X1/X4))))
# <lambdifygenerated-1282>:2: RuntimeWarning: invalid value encountered in subtract
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X5*(X3 + l) + X6 - exp(X1/X4))))
# <lambdifygenerated-1283>:2: RuntimeWarning: overflow encountered in exp
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X5*(X3 + l) + X6 - exp(X1/X4))))
# <lambdifygenerated-1283>:2: RuntimeWarning: invalid value encountered in subtract
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X5*(X3 + l) + X6 - exp(X1/X4))))
# <lambdifygenerated-1284>:2: RuntimeWarning: overflow encountered in exp
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X5*(X3 + l) + X6 - exp(X1/X4))))
# <lambdifygenerated-1284>:2: RuntimeWarning: invalid value encountered in subtract
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X5*(X3 + l) + X6 - exp(X1/X4))))
# <lambdifygenerated-1285>:2: RuntimeWarning: overflow encountered in exp
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X5*(X3 + l) + X6 - exp(X1/X4))))
# <lambdifygenerated-1285>:2: RuntimeWarning: invalid value encountered in subtract
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X5*(X3 + l) + X6 - exp(X1/X4))))
# <lambdifygenerated-1286>:2: RuntimeWarning: overflow encountered in exp
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*X5 + X6 + l - exp(X1/X4))))
# <lambdifygenerated-1286>:2: RuntimeWarning: invalid value encountered in subtract
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*X5 + X6 + l - exp(X1/X4))))
# <lambdifygenerated-1287>:2: RuntimeWarning: overflow encountered in exp
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*X5 + X6 + l - exp(X1/X4))))
# <lambdifygenerated-1287>:2: RuntimeWarning: invalid value encountered in subtract
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*X5 + X6 + l - exp(X1/X4))))
# <lambdifygenerated-1288>:2: RuntimeWarning: overflow encountered in exp
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*X5 + X6 + l - exp(X1/X4))))
# <lambdifygenerated-1288>:2: RuntimeWarning: invalid value encountered in subtract
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*X5 + X6 + l - exp(X1/X4))))
# <lambdifygenerated-1289>:2: RuntimeWarning: overflow encountered in exp
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*X5 + X6 + l - exp(X1/X4))))
# <lambdifygenerated-1289>:2: RuntimeWarning: invalid value encountered in subtract
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*X5 + X6 + l - exp(X1/X4))))
# <lambdifygenerated-1290>:2: RuntimeWarning: overflow encountered in exp
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*X5 + X6 + l - exp(X1/X4))))
# <lambdifygenerated-1290>:2: RuntimeWarning: invalid value encountered in subtract
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*X5 + X6 + l - exp(X1/X4))))
# <lambdifygenerated-1291>:2: RuntimeWarning: overflow encountered in exp
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*X5 + X6 + l - exp(X1/X4))))
# <lambdifygenerated-1291>:2: RuntimeWarning: invalid value encountered in subtract
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*X5 + X6 + l - exp(X1/X4))))
# <lambdifygenerated-1294>:2: RuntimeWarning: overflow encountered in exp
#   return -(exp(sqrt(abs(X0 + X4))) + abs(sin(X6)))*sqrt(abs(X1 + exp(X1)*sqrt(abs(X6)))) + (exp(sqrt(abs(X0 + X4 + l))) + abs(sin(X6)))*sqrt(abs(X1 + exp(X1)*sqrt(abs(X6)))) + exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/(X4 + l)))))
# <lambdifygenerated-1294>:2: RuntimeWarning: invalid value encountered in subtract
#   return -(exp(sqrt(abs(X0 + X4))) + abs(sin(X6)))*sqrt(abs(X1 + exp(X1)*sqrt(abs(X6)))) + (exp(sqrt(abs(X0 + X4 + l))) + abs(sin(X6)))*sqrt(abs(X1 + exp(X1)*sqrt(abs(X6)))) + exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/(X4 + l)))))
# <lambdifygenerated-1296>:2: RuntimeWarning: overflow encountered in exp
#   return -(exp(sqrt(abs(X0 + X4))) + abs(sin(X6)))*sqrt(abs(X1 + exp(X1)*sqrt(abs(X6)))) + (exp(sqrt(abs(X0 + X4 + l))) + abs(sin(X6)))*sqrt(abs(X1 + exp(X1)*sqrt(abs(X6)))) + exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/(X4 + l)))))
# <lambdifygenerated-1297>:2: RuntimeWarning: overflow encountered in exp
#   return -(exp(sqrt(abs(X0 + X4))) + abs(sin(X6)))*sqrt(abs(X1 + exp(X1)*sqrt(abs(X6)))) + (exp(sqrt(abs(X0 + X4 + l))) + abs(sin(X6)))*sqrt(abs(X1 + exp(X1)*sqrt(abs(X6)))) + exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/(X4 + l)))))
# <lambdifygenerated-1298>:2: RuntimeWarning: overflow encountered in exp
#   return -(exp(sqrt(abs(X0 + X4))) + abs(sin(X6)))*sqrt(abs(X1 + exp(X1)*sqrt(abs(X6)))) + (exp(sqrt(abs(X0 + X4 + l))) + abs(sin(X6)))*sqrt(abs(X1 + exp(X1)*sqrt(abs(X6)))) + exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/(X4 + l)))))
# <lambdifygenerated-1299>:2: RuntimeWarning: overflow encountered in exp
#   return -(exp(sqrt(abs(X0 + X4))) + abs(sin(X6)))*sqrt(abs(X1 + exp(X1)*sqrt(abs(X6)))) + (exp(sqrt(abs(X0 + X4))) + abs(sin(X6)))*sqrt(abs(X1 + l + exp(X1 + l)*sqrt(abs(X6)))) + exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*X5 + X6 - exp((X1 + l)/X4))))
# <lambdifygenerated-1300>:2: RuntimeWarning: overflow encountered in exp
#   return -(exp(sqrt(abs(X0 + X4))) + abs(sin(X6)))*sqrt(abs(X1 + exp(X1)*sqrt(abs(X6)))) + (exp(sqrt(abs(X0 + X4))) + abs(sin(X6)))*sqrt(abs(X1 + l + exp(X1 + l)*sqrt(abs(X6)))) + exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*X5 + X6 - exp((X1 + l)/X4))))
# <lambdifygenerated-1301>:2: RuntimeWarning: overflow encountered in exp
#   return -(exp(sqrt(abs(X0 + X4))) + abs(sin(X6)))*sqrt(abs(X1 + exp(X1)*sqrt(abs(X6)))) + (exp(sqrt(abs(X0 + X4))) + abs(sin(X6)))*sqrt(abs(X1 + l + exp(X1 + l)*sqrt(abs(X6)))) + exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*X5 + X6 - exp((X1 + l)/X4))))
# <lambdifygenerated-1301>:2: RuntimeWarning: invalid value encountered in subtract
#   return -(exp(sqrt(abs(X0 + X4))) + abs(sin(X6)))*sqrt(abs(X1 + exp(X1)*sqrt(abs(X6)))) + (exp(sqrt(abs(X0 + X4))) + abs(sin(X6)))*sqrt(abs(X1 + l + exp(X1 + l)*sqrt(abs(X6)))) + exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*X5 + X6 - exp((X1 + l)/X4))))
# <lambdifygenerated-1302>:2: RuntimeWarning: overflow encountered in exp
#   return -(exp(sqrt(abs(X0 + X4))) + abs(sin(X6)))*sqrt(abs(X1 + exp(X1)*sqrt(abs(X6)))) + (exp(sqrt(abs(X0 + X4))) + abs(sin(X6)))*sqrt(abs(X1 + l + exp(X1 + l)*sqrt(abs(X6)))) + exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*X5 + X6 - exp((X1 + l)/X4))))
# <lambdifygenerated-1303>:2: RuntimeWarning: overflow encountered in exp
#   return -(exp(sqrt(abs(X0 + X4))) + abs(sin(X6)))*sqrt(abs(X1 + exp(X1)*sqrt(abs(X6)))) + (exp(sqrt(abs(X0 + X4))) + abs(sin(X6)))*sqrt(abs(X1 + l + exp(X1 + l)*sqrt(abs(X6)))) + exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*X5 + X6 - exp((X1 + l)/X4))))
# <lambdifygenerated-1304>:2: RuntimeWarning: overflow encountered in exp
#   return -(exp(sqrt(abs(X0 + X4))) + abs(sin(X6)))*sqrt(abs(X1 + exp(X1)*sqrt(abs(X6)))) + (exp(sqrt(abs(X0 + X4))) + abs(sin(X6)))*sqrt(abs(X1 + l + exp(X1 + l)*sqrt(abs(X6)))) + exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*X5 + X6 - exp((X1 + l)/X4))))
# <lambdifygenerated-1305>:2: RuntimeWarning: overflow encountered in exp
#   return -(exp(sqrt(abs(X0 + X4))) + abs(sin(X6)))*sqrt(abs(X1 + exp(X1)*sqrt(abs(X6)))) + (exp(sqrt(abs(X0 + X4))) + abs(sin(X6)))*sqrt(abs(X1 + l + exp(X1 + l)*sqrt(abs(X6)))) + exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*X5 + X6 - exp((X1 + l)/X4))))
# <lambdifygenerated-1310>:2: RuntimeWarning: overflow encountered in exp
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*(X5 + l) + X6 - exp(X1/X4))))
# <lambdifygenerated-1310>:2: RuntimeWarning: invalid value encountered in subtract
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*(X5 + l) + X6 - exp(X1/X4))))
# <lambdifygenerated-1311>:2: RuntimeWarning: overflow encountered in exp
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*(X5 + l) + X6 - exp(X1/X4))))
# <lambdifygenerated-1311>:2: RuntimeWarning: invalid value encountered in subtract
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*(X5 + l) + X6 - exp(X1/X4))))
# <lambdifygenerated-1312>:2: RuntimeWarning: overflow encountered in exp
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*(X5 + l) + X6 - exp(X1/X4))))
# <lambdifygenerated-1312>:2: RuntimeWarning: invalid value encountered in subtract
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*(X5 + l) + X6 - exp(X1/X4))))
# <lambdifygenerated-1313>:2: RuntimeWarning: overflow encountered in exp
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*(X5 + l) + X6 - exp(X1/X4))))
# <lambdifygenerated-1313>:2: RuntimeWarning: invalid value encountered in subtract
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*(X5 + l) + X6 - exp(X1/X4))))
# <lambdifygenerated-1314>:2: RuntimeWarning: overflow encountered in exp
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*(X5 + l) + X6 - exp(X1/X4))))
# <lambdifygenerated-1314>:2: RuntimeWarning: invalid value encountered in subtract
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*(X5 + l) + X6 - exp(X1/X4))))
# <lambdifygenerated-1315>:2: RuntimeWarning: overflow encountered in exp
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*(X5 + l) + X6 - exp(X1/X4))))
# <lambdifygenerated-1315>:2: RuntimeWarning: invalid value encountered in subtract
#   return exp(sqrt(abs(X2 + X3*X5 + X6 - exp(X1/X4)))) - exp(sqrt(abs(X2 + X3*(X5 + l) + X6 - exp(X1/X4))))
# ...
# <lambdifygenerated-58591>:2: RuntimeWarning: overflow encountered in exp
#   return -0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1))) + 0.65838229666046*exp(X0 + X1*(X4 + l - 0.707519695844965)/X2 + X2 + X3 + X4 + l + exp(X1) - exp(-exp(X4 + l) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1)))
# <lambdifygenerated-58591>:2: RuntimeWarning: invalid value encountered in add
#   return -0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1))) + 0.65838229666046*exp(X0 + X1*(X4 + l - 0.707519695844965)/X2 + X2 + X3 + X4 + l + exp(X1) - exp(-exp(X4 + l) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1)))
# <lambdifygenerated-58592>:2: RuntimeWarning: overflow encountered in exp
#   return -0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1))) + 0.65838229666046*exp(X0 + X1*(X4 + l - 0.707519695844965)/X2 + X2 + X3 + X4 + l + exp(X1) - exp(-exp(X4 + l) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1)))
# <lambdifygenerated-58592>:2: RuntimeWarning: invalid value encountered in add
#   return -0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1))) + 0.65838229666046*exp(X0 + X1*(X4 + l - 0.707519695844965)/X2 + X2 + X3 + X4 + l + exp(X1) - exp(-exp(X4 + l) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1)))
# <lambdifygenerated-58593>:2: RuntimeWarning: overflow encountered in exp
#   return -0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1))) + 0.65838229666046*exp(X0 + X1*(X4 + l - 0.707519695844965)/X2 + X2 + X3 + X4 + l + exp(X1) - exp(-exp(X4 + l) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1)))
# <lambdifygenerated-58593>:2: RuntimeWarning: invalid value encountered in add
#   return -0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1))) + 0.65838229666046*exp(X0 + X1*(X4 + l - 0.707519695844965)/X2 + X2 + X3 + X4 + l + exp(X1) - exp(-exp(X4 + l) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1)))
# <lambdifygenerated-58595>:2: RuntimeWarning: overflow encountered in exp
#   return -0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1))) + 0.65838229666046*exp(X0 + X1*(X4 + l - 0.707519695844965)/X2 + X2 + X3 + X4 + l + exp(X1) - exp(-exp(X4 + l) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1)))
# <lambdifygenerated-58595>:2: RuntimeWarning: invalid value encountered in add
#   return -0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1))) + 0.65838229666046*exp(X0 + X1*(X4 + l - 0.707519695844965)/X2 + X2 + X3 + X4 + l + exp(X1) - exp(-exp(X4 + l) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1)))
# <lambdifygenerated-58596>:2: RuntimeWarning: overflow encountered in exp
#   return -0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1))) + 0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + l + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1)))
# <lambdifygenerated-58596>:2: RuntimeWarning: invalid value encountered in add
#   return -0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1))) + 0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + l + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1)))
# <lambdifygenerated-58597>:2: RuntimeWarning: overflow encountered in exp
#   return -0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1))) + 0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + l + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1)))
# <lambdifygenerated-58597>:2: RuntimeWarning: invalid value encountered in add
#   return -0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1))) + 0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + l + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1)))
# <lambdifygenerated-58598>:2: RuntimeWarning: overflow encountered in exp
#   return -0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1))) + 0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + l + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1)))
# <lambdifygenerated-58598>:2: RuntimeWarning: invalid value encountered in add
#   return -0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1))) + 0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + l + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1)))
# <lambdifygenerated-58600>:2: RuntimeWarning: overflow encountered in exp
#   return -0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1))) + 0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + l + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1)))
# <lambdifygenerated-58600>:2: RuntimeWarning: invalid value encountered in add
#   return -0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1))) + 0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + l + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1)))
# <lambdifygenerated-58601>:2: RuntimeWarning: overflow encountered in exp
#   return -0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1))) + 0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/(X2 + l) + X2 + X3 + X4 + l + exp(X1) - exp(-exp(X4) + sqrt(abs(X2 + l))) + sin(exp((X2 + l)**2)))/abs(log(abs(X1)))
# <lambdifygenerated-58601>:2: RuntimeWarning: invalid value encountered in add
#   return -0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1))) + 0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/(X2 + l) + X2 + X3 + X4 + l + exp(X1) - exp(-exp(X4) + sqrt(abs(X2 + l))) + sin(exp((X2 + l)**2)))/abs(log(abs(X1)))
# <lambdifygenerated-58602>:2: RuntimeWarning: overflow encountered in exp
#   return -0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1))) + 0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/(X2 + l) + X2 + X3 + X4 + l + exp(X1) - exp(-exp(X4) + sqrt(abs(X2 + l))) + sin(exp((X2 + l)**2)))/abs(log(abs(X1)))
# <lambdifygenerated-58602>:2: RuntimeWarning: invalid value encountered in add
#   return -0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1))) + 0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/(X2 + l) + X2 + X3 + X4 + l + exp(X1) - exp(-exp(X4) + sqrt(abs(X2 + l))) + sin(exp((X2 + l)**2)))/abs(log(abs(X1)))
# <lambdifygenerated-58603>:2: RuntimeWarning: overflow encountered in exp
#   return -0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1))) + 0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/(X2 + l) + X2 + X3 + X4 + l + exp(X1) - exp(-exp(X4) + sqrt(abs(X2 + l))) + sin(exp((X2 + l)**2)))/abs(log(abs(X1)))
# <lambdifygenerated-58603>:2: RuntimeWarning: invalid value encountered in add
#   return -0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1))) + 0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/(X2 + l) + X2 + X3 + X4 + l + exp(X1) - exp(-exp(X4) + sqrt(abs(X2 + l))) + sin(exp((X2 + l)**2)))/abs(log(abs(X1)))
# <lambdifygenerated-58605>:2: RuntimeWarning: overflow encountered in exp
#   return -0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1))) + 0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/(X2 + l) + X2 + X3 + X4 + l + exp(X1) - exp(-exp(X4) + sqrt(abs(X2 + l))) + sin(exp((X2 + l)**2)))/abs(log(abs(X1)))
# <lambdifygenerated-58605>:2: RuntimeWarning: invalid value encountered in add
#   return -0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/X2 + X2 + X3 + X4 + exp(X1) - exp(-exp(X4) + sqrt(abs(X2))) + sin(exp(X2**2)))/abs(log(abs(X1))) + 0.65838229666046*exp(X0 + X1*(X4 - 0.707519695844965)/(X2 + l) + X2 + X3 + X4 + l + exp(X1) - exp(-exp(X4) + sqrt(abs(X2 + l))) + sin(exp((X2 + l)**2)))/abs(log(abs(X1)))
# <lambdifygenerated-58763>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(exp(2*X0 + X2 - X5)) + exp(exp(2*X0 + X2 - X5 - l))
# <lambdifygenerated-58763>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(exp(2*X0 + X2 - X5)) + exp(exp(2*X0 + X2 - X5 - l))
# <lambdifygenerated-58764>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(exp(2*X0 + X2 - X5)) + exp(exp(2*X0 + X2 - X5 - l))
# <lambdifygenerated-58764>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(exp(2*X0 + X2 - X5)) + exp(exp(2*X0 + X2 - X5 - l))
# <lambdifygenerated-58765>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(exp(2*X0 + X2 - X5)) + exp(exp(2*X0 + X2 - X5 - l))
# <lambdifygenerated-58765>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(exp(2*X0 + X2 - X5)) + exp(exp(2*X0 + X2 - X5 - l))
# <lambdifygenerated-58766>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(exp(2*X0 + X2 - X5)) + exp(exp(2*X0 + X2 - X5 + 2*l))
# <lambdifygenerated-58766>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(exp(2*X0 + X2 - X5)) + exp(exp(2*X0 + X2 - X5 + 2*l))
# <lambdifygenerated-58767>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(exp(2*X0 + X2 - X5)) + exp(exp(2*X0 + X2 - X5 + 2*l))
# <lambdifygenerated-58767>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(exp(2*X0 + X2 - X5)) + exp(exp(2*X0 + X2 - X5 + 2*l))
# <lambdifygenerated-58768>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(exp(2*X0 + X2 - X5)) + exp(exp(2*X0 + X2 - X5 + 2*l))
# <lambdifygenerated-58768>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(exp(2*X0 + X2 - X5)) + exp(exp(2*X0 + X2 - X5 + 2*l))
# <lambdifygenerated-58769>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(exp(2*X0 + X2 - X5)) + exp(exp(2*X0 + X2 - X5 + l))
# <lambdifygenerated-58769>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(exp(2*X0 + X2 - X5)) + exp(exp(2*X0 + X2 - X5 + l))
# <lambdifygenerated-58770>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(exp(2*X0 + X2 - X5)) + exp(exp(2*X0 + X2 - X5 + l))
# <lambdifygenerated-58770>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(exp(2*X0 + X2 - X5)) + exp(exp(2*X0 + X2 - X5 + l))
# <lambdifygenerated-58771>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(exp(2*X0 + X2 - X5)) + exp(exp(2*X0 + X2 - X5 + l))
# <lambdifygenerated-58771>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(exp(2*X0 + X2 - X5)) + exp(exp(2*X0 + X2 - X5 + l))
# <lambdifygenerated-58844>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X3/X4) + exp((X3 + l)/X4)
# <lambdifygenerated-58844>:2: RuntimeWarning: invalid value encountered in add
#   return -exp(X3/X4) + exp((X3 + l)/X4)
# <lambdifygenerated-58846>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(X3/X4) + exp(X3/(X4 + l))
# <lambdifygenerated-58941>:2: RuntimeWarning: overflow encountered in exp
#   return -sqrt(exp(exp(X1)/(X1 + X5))) + sqrt(exp(exp(X1 + l)/(X1 + X5 + l))) + 0.882228491290235*exp(sqrt(abs(X6))/log(abs(X0)))*abs(X1)**(1/4) - 0.882228491290235*exp(sqrt(abs(X6))/log(abs(X0)))*abs(X1 + l)**(1/4)
# <lambdifygenerated-58942>:2: RuntimeWarning: overflow encountered in exp
#   return -sqrt(exp(exp(X1)/(X1 + X5))) + sqrt(exp(exp(X1 + l)/(X1 + X5 + l))) + 0.882228491290235*exp(sqrt(abs(X6))/log(abs(X0)))*abs(X1)**(1/4) - 0.882228491290235*exp(sqrt(abs(X6))/log(abs(X0)))*abs(X1 + l)**(1/4)
# <lambdifygenerated-58943>:2: RuntimeWarning: overflow encountered in exp
#   return -sqrt(exp(exp(X1)/(X1 + X5))) + sqrt(exp(exp(X1 + l)/(X1 + X5 + l))) + 0.882228491290235*exp(sqrt(abs(X6))/log(abs(X0)))*abs(X1)**(1/4) - 0.882228491290235*exp(sqrt(abs(X6))/log(abs(X0)))*abs(X1 + l)**(1/4)
# <lambdifygenerated-58944>:2: RuntimeWarning: overflow encountered in exp
#   return -sqrt(exp(exp(X1)/(X1 + X5))) + sqrt(exp(exp(X1 + l)/(X1 + X5 + l))) + 0.882228491290235*exp(sqrt(abs(X6))/log(abs(X0)))*abs(X1)**(1/4) - 0.882228491290235*exp(sqrt(abs(X6))/log(abs(X0)))*abs(X1 + l)**(1/4)
# <lambdifygenerated-58949>:2: RuntimeWarning: overflow encountered in exp
#   return -sqrt(exp(exp(X1)/(X1 + X5))) + sqrt(exp(exp(X1)/(X1 + X5 + l)))
# <lambdifygenerated-58949>:2: RuntimeWarning: invalid value encountered in add
#   return -sqrt(exp(exp(X1)/(X1 + X5))) + sqrt(exp(exp(X1)/(X1 + X5 + l)))
# <lambdifygenerated-58962>:2: RuntimeWarning: overflow encountered in exp
#   return -exp(exp(X2)) + exp(exp(X2 + l))
# <lambdifygenerated-59103>:2: RuntimeWarning: overflow encountered in exp
#   return -(exp(sqrt(abs(X0*X5))) + log(abs(-X2 + X3 + 1.32186064395729*X5)))/log(sqrt(abs(X2*(X4 + l)/log(abs(X6))))) + (exp(sqrt(abs(X0*X5))) + log(abs(-X2 + X3 + 1.32186064395729*X5)))/log(sqrt(abs(X2*X4/log(abs(X6))))) - exp(exp(abs(X0)**(1/4)*sqrt(abs(X4 - 0.0972654216474611)))) + exp(exp(abs(X0)**(1/4)*sqrt(abs(X4 + l - 0.0972654216474611))))
# <lambdifygenerated-59104>:2: RuntimeWarning: overflow encountered in exp
#   return -(exp(sqrt(abs(X0*X5))) + log(abs(-X2 + X3 + 1.32186064395729*X5)))/log(sqrt(abs(X2*(X4 + l)/log(abs(X6))))) + (exp(sqrt(abs(X0*X5))) + log(abs(-X2 + X3 + 1.32186064395729*X5)))/log(sqrt(abs(X2*X4/log(abs(X6))))) - exp(exp(abs(X0)**(1/4)*sqrt(abs(X4 - 0.0972654216474611)))) + exp(exp(abs(X0)**(1/4)*sqrt(abs(X4 + l - 0.0972654216474611))))
# <lambdifygenerated-59107>:2: RuntimeWarning: overflow encountered in exp
#   return -(exp(sqrt(abs(X0*X5))) + log(abs(-X2 + X3 + 1.32186064395729*X5)))/log(sqrt(abs(X2*(X4 + l)/log(abs(X6))))) + (exp(sqrt(abs(X0*X5))) + log(abs(-X2 + X3 + 1.32186064395729*X5)))/log(sqrt(abs(X2*X4/log(abs(X6))))) - exp(exp(abs(X0)**(1/4)*sqrt(abs(X4 - 0.0972654216474611)))) + exp(exp(abs(X0)**(1/4)*sqrt(abs(X4 + l - 0.0972654216474611))))
# <lambdifygenerated-59108>:2: RuntimeWarning: overflow encountered in exp
#   return -(exp(sqrt(abs(X0*X5))) + log(abs(-X2 + X3 + 1.32186064395729*X5)))/log(sqrt(abs(X2*(X4 + l)/log(abs(X6))))) + (exp(sqrt(abs(X0*X5))) + log(abs(-X2 + X3 + 1.32186064395729*X5)))/log(sqrt(abs(X2*X4/log(abs(X6))))) - exp(exp(abs(X0)**(1/4)*sqrt(abs(X4 - 0.0972654216474611)))) + exp(exp(abs(X0)**(1/4)*sqrt(abs(X4 + l - 0.0972654216474611))))

# %%
c1_max_list = []
for c1 in c1_list:
    if len(c1) == 0:
        c1_max_list.append(0)
    else:
        c1_max = max(c1.values())
        c1_max_list.append(c1_max)

c1_mean_list = []
for c1 in c1_list:
    if len(c1) == 0:
        c1_mean_list.append(0)
    else:
        c1_mean = np.mean(list(c1.values()))
        c1_mean_list.append(c1_mean)

length_list = []
for program in new_programs:
    length_list.append(len(program.program))

c1_sum_list = []
for c1 in c1_list:
    if len(c1) == 0:
        c1_sum_list.append(0)
    else:
        c1_sum = np.sum(list(c1.values()))
        c1_sum_list.append(c1_sum)

# %%
from gplearn_sgpa.functions import _Function


def count_ops(expr):
    """ Counts the number of operations in the formula """
    formula = str(expr).replace('**','^')
    ops = 0
    for sim in  ['+', '-', '*', '/', '^', 'sin', 'cos', 'exp', 'log', 'sqrt']:
        ops += formula.count(sim)
    return ops

def count_na_ops(expr):
    """ Counts the number of non-arithmetic operations (^,sqrt,sin,cos) in the formula """
    formula = str(expr).replace('**','^')
    ops = 0
    for sim in  ['^', 'sin', 'cos', 'exp', 'log', 'sqrt']:
        ops += formula.count(sim)
    return ops

n_o = []
for expr in sympy_exp_list:
    n = count_ops(expr)
    n_o.append(n)

n_nao = []
for expr in sympy_exp_list:
    n = count_na_ops(expr)
    n_nao.append(n)

def count_nodes(expr, n_nodes = None):
    """ Counts the number of nodes in the simpy tree representation of the formula """
    if n_nodes is None:
        n_nodes = 1
    if len(expr.args)>0:
        n_nodes += len(expr.args)
        if str(type(expr)) == 'Abs':
            n_nodes -= 1
        # a/x is read as a*(1/x)
        if expr.is_Mul and any([arg.is_Pow for arg in expr.args]):
            for arg in expr.args:
                if arg.is_Pow and arg.args[1] == -1:
                    n_nodes -= 2
        # -x is read as -1*x
        if expr.is_Mul and (expr.args[0] == -1):
            n_nodes -= 1
        for arg in expr.args:
            n_nodes = count_nodes(arg, n_nodes)
    return n_nodes

n_l = []
for expr in sympy_exp_list:
    n = count_nodes(expr)
    n_l.append(n)


def count_na_comp(expr, count=None):
    """ Counts the maximum number of non-arithmetic chained operations in the formula, e.g. for log(sin(cos(x)) 
    the function returns 3 """
    if count == None:
        count = 0
    if (expr.is_Pow and expr.args[1]!=-1) or (str(type(expr)) in ['sin','log','exp','Abs']):
        if str(type(expr)) != 'Abs':
            count += 1
        count_args = []
        for arg in expr.args:
            count_args.append(count_na_comp(arg, count))
        count = max(count_args)
        return count
    else:
        if expr.args:
            count_args = []
            for arg in expr.args:
                count_args.append(count_na_comp(arg, count))
            count = max(count_args)
        return count

n_naoc = []
for expr in sympy_exp_list:
    n_naoc.append(count_na_comp(expr))

# %%
df = pd.DataFrame({'expr':[str(s) for s in sympy_exp_list],'length': n_l, 'c1_max': c1_max_list, 'c1_mean': c1_mean_list, 'c1_sum':c1_sum_list, 'n_o': n_o, 'n_nao': n_nao, 'n_naoc': n_naoc})

# %%
df.head()
# Out:
#                                                 expr  length  c1_max  c1_mean  \
# 0  sqrt(exp(1.94924425764298*exp(X1)/(log(Abs(X0)...      31       2      2.0
# 1  exp((log(Abs(X0)) + 0.903266733865905)*exp(-X0...      13       1      1.0
# 2                                  0.965234885451848       1       0      0.0
# 3  0.518070542841815*X0*X1**2*(X0 + 0.11613157053...       9       1      0.5
# 4                        exp(Abs(X1*sin(X0))**(1/4))       7       2      2.0
#
#    c1_sum  n_o  n_nao  n_naoc
# 0       4   22     11       3
# 1       1    8      3       2
# 2       0    0      0       0
# 3       1    5      1       1
# 4       4    5      3       3

# %%
df['proxy'] = 79.1 - 0.2*df['length'] - 0.5*df['n_o'] - 3.4*df['n_nao'] - 4.5*df['n_naoc']

# %%
import matplotlib as mpl

# Enable LaTeX rendering
mpl.rcParams.update(mpl.rcParamsDefault)
mpl.rcParams['text.usetex'] = False
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# Subplot 1: c1_max vs proxy
axes[0].scatter(df['c1_max'], df['proxy'], alpha=0.5)
axes[0].set_title(r"Correlation between max($c_1$) and $\mathcal{M}^{\phi}$")
axes[0].set_xlabel(r'max($c_1$)')
axes[0].set_ylabel(r'$\mathcal{M}^{\phi}$')
pearson_corr, _ = pearsonr(df['c1_max'], df['proxy'])
spearman_corr, _ = spearmanr(df['c1_max'], df['proxy'])
axes[0].text(0.6, 0.95, f'Pearson: {pearson_corr:.2f}\nSpearman: {spearman_corr:.2f}', 
             transform=axes[0].transAxes, fontsize=12, verticalalignment='top')

# Subplot 2: c1_mean vs proxy
axes[1].scatter(df['c1_mean'], df['proxy'], alpha=0.5)
axes[1].set_title(r'Correlation between mean($c_1$) and $\mathcal{M}^{\phi}$')
axes[1].set_xlabel(r'mean($c_1$)')
axes[1].set_ylabel(r'$\mathcal{M}^{\phi}$')
pearson_corr, _ = pearsonr(df['c1_mean'], df['proxy'])
spearman_corr, _ = spearmanr(df['c1_mean'], df['proxy'])
axes[1].text(0.6, 0.95, f'Pearson: {pearson_corr:.2f}\nSpearman: {spearman_corr:.2f}', 
             transform=axes[1].transAxes, fontsize=12, verticalalignment='top')

# Subplot 3: c1_sum vs proxy
axes[2].scatter(df['c1_sum'], df['proxy'], alpha=0.5)
axes[2].set_title(r'Correlation between sum($c_1$) and $\mathcal{M}^{\phi}$')
axes[2].set_xlabel(r'sum($c_1$)')
axes[2].set_ylabel(r'$\mathcal{M}^{\phi}$')
pearson_corr, _ = pearsonr(df['c1_sum'], df['proxy'])
spearman_corr, _ = spearmanr(df['c1_sum'], df['proxy'])
axes[2].text(0.6, 0.95, f'Pearson: {pearson_corr:.2f}\nSpearman: {spearman_corr:.2f}', 
             transform=axes[2].transAxes, fontsize=12, verticalalignment='top')

plt.tight_layout()

import os
# Create a folder if it does not exist
if not os.path.exists('results'):
    os.makedirs('results')

# Save the figure
plt.savefig('results/correlation.png')
